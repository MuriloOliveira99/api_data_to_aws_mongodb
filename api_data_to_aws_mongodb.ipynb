# %% [markdown]
# # Salvando Dados da FakerAPI difentes destinos e formatos
# Fonte dos Dados: https://fakerapi.it/en
# - MongoDB
# - AWS S3
# - CSV
# - json
# - Parquet

# %% [markdown]
# ## Importando as libs necessárias

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
import requests
import json
import boto3

# MongoDB
user = ''
password = ''
collection = ''

# %% [markdown]
# ## Criando uma Sesssão Spark

# %%
spark = (
    SparkSession
    .builder
    .master('local')
    .appName('api_to_mongodb')
    .getOrCreate()
)

# %% [markdown]
# ## Fazendo a requisição da API

# %%
def requests_api():
    try:
        r = requests.get('https://fakerapi.it/api/v1/persons?_quantity=100')
        r.raise_for_status()
        return r
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
        return None

# %%
requests_api()
# Out:
# <Response [200]>

# %% [markdown]
# ## Obtendo os Dados da API

# %%
def get_data(): 
    try:
        data = requests_api()
        return data.json()['data']
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
        return None

# %%
get_data()
# Out:
# [{'id': 1,
#   'firstname': 'Marjolaine',
#   'lastname': 'Rosenbaum',
#   'email': 'handerson@gmail.com',
#   'phone': '+7454666536414',
#   'birthday': '1971-11-18',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '338 Langosh Gardens',
#    'streetName': "O'Connell Camp",
#    'buildingNumber': '6842',
#    'city': 'Port Paoloburgh',
#    'zipcode': '55359-9514',
#    'country': 'Netherlands',
#    'county_code': 'WF',
#    'latitude': 65.13877,
#    'longitude': 175.247248},
#   'website': 'http://lesch.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 2,
#   'firstname': 'Demetrius',
#   'lastname': 'Bode',
#   'email': 'sward@cronin.com',
#   'phone': '+5447141694359',
#   'birthday': '1963-05-05',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '680 Brakus Cliffs Suite 494',
#    'streetName': 'Gutkowski Key',
#    'buildingNumber': '9790',
#    'city': 'Mohrmouth',
#    'zipcode': '88611',
#    'country': 'Falkland Islands (Malvinas)',
#    'county_code': 'GL',
#    'latitude': -46.855216,
#    'longitude': -146.724879},
#   'website': 'http://schiller.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 3,
#   'firstname': 'Candelario',
#   'lastname': 'Beahan',
#   'email': 'pgoyette@waters.com',
#   'phone': '+1082553455764',
#   'birthday': '1981-04-13',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '12800 Vandervort Mall',
#    'streetName': 'Assunta Mission',
#    'buildingNumber': '3464',
#    'city': 'New Sammiemouth',
#    'zipcode': '55971',
#    'country': 'Kazakhstan',
#    'county_code': 'MS',
#    'latitude': 60.245492,
#    'longitude': -116.952027},
#   'website': 'http://gibson.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 4,
#   'firstname': 'Imelda',
#   'lastname': 'Johns',
#   'email': 'jettie22@jenkins.info',
#   'phone': '+7732058157137',
#   'birthday': '1949-07-01',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '56358 Karlie Ports',
#    'streetName': 'Margarette Rapids',
#    'buildingNumber': '89759',
#    'city': 'Lake Brandi',
#    'zipcode': '28723-3886',
#    'country': 'Anguilla',
#    'county_code': 'PY',
#    'latitude': -83.05125,
#    'longitude': -26.893749},
#   'website': 'http://ryan.org',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 5,
#   'firstname': 'Leda',
#   'lastname': 'Harris',
#   'email': 'amarks@gmail.com',
#   'phone': '+5871251961195',
#   'birthday': '2012-08-03',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '1801 Strosin Pine Apt. 095',
#    'streetName': 'Bauch Plaza',
#    'buildingNumber': '4927',
#    'city': 'Dibbertport',
#    'zipcode': '62439-8439',
#    'country': 'Saint Barthelemy',
#    'county_code': 'PT',
#    'latitude': -46.119256,
#    'longitude': 95.229348},
#   'website': 'http://jakubowski.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 6,
#   'firstname': 'Edwardo',
#   'lastname': 'Runolfsson',
#   'email': 'stehr.cayla@gmail.com',
#   'phone': '+3702075587698',
#   'birthday': '1981-02-19',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '448 Kathryn Islands Apt. 214',
#    'streetName': 'Kassandra Mission',
#    'buildingNumber': '828',
#    'city': 'North Donnie',
#    'zipcode': '43276',
#    'country': 'Sweden',
#    'county_code': 'BT',
#    'latitude': 65.243633,
#    'longitude': -18.168043},
#   'website': 'http://ruecker.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 7,
#   'firstname': 'Gustave',
#   'lastname': 'Oberbrunner',
#   'email': 'tito.kreiger@gmail.com',
#   'phone': '+9957181130877',
#   'birthday': '1939-07-09',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '892 Sandrine Valleys Apt. 199',
#    'streetName': 'Kaya Track',
#    'buildingNumber': '73029',
#    'city': 'Lake Hermina',
#    'zipcode': '00178',
#    'country': 'Nepal',
#    'county_code': 'PL',
#    'latitude': 74.180627,
#    'longitude': -170.922588},
#   'website': 'http://sawayn.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 8,
#   'firstname': 'Cooper',
#   'lastname': 'Quitzon',
#   'email': 'oda.stracke@aufderhar.com',
#   'phone': '+3376130972305',
#   'birthday': '1936-01-23',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': "943 D'Amore Springs",
#    'streetName': 'Wanda Drives',
#    'buildingNumber': '82952',
#    'city': 'East Trace',
#    'zipcode': '24293-0982',
#    'country': 'Central African Republic',
#    'county_code': 'ST',
#    'latitude': 64.897191,
#    'longitude': -177.907514},
#   'website': 'http://quitzon.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 9,
#   'firstname': 'Muhammad',
#   'lastname': 'Purdy',
#   'email': 'watson00@gmail.com',
#   'phone': '+1223508449060',
#   'birthday': '1983-12-26',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '6301 Laura Hill Apt. 605',
#    'streetName': 'Aisha Brook',
#    'buildingNumber': '412',
#    'city': 'East Gaetano',
#    'zipcode': '66249',
#    'country': 'Oman',
#    'county_code': 'CL',
#    'latitude': -62.574066,
#    'longitude': 13.385445},
#   'website': 'http://terry.net',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 10,
#   'firstname': 'Marilie',
#   'lastname': 'Stoltenberg',
#   'email': 'cristina.stamm@gmail.com',
#   'phone': '+8984952291535',
#   'birthday': '1961-01-30',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '404 Collins Harbors Suite 549',
#    'streetName': 'Isac Park',
#    'buildingNumber': '54483',
#    'city': 'New Henriside',
#    'zipcode': '04550',
#    'country': 'Panama',
#    'county_code': 'KP',
#    'latitude': 80.542752,
#    'longitude': 39.732754},
#   'website': 'http://klocko.net',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 11,
#   'firstname': 'Marlin',
#   'lastname': 'Stamm',
#   'email': 'mnikolaus@gmail.com',
#   'phone': '+4973986650770',
#   'birthday': '2005-04-10',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '9592 Lysanne Meadow',
#    'streetName': 'Jaunita Via',
#    'buildingNumber': '183',
#    'city': 'Lake Laverna',
#    'zipcode': '72810-9450',
#    'country': 'Spain',
#    'county_code': 'ET',
#    'latitude': -81.425674,
#    'longitude': 84.710817},
#   'website': 'http://streich.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 12,
#   'firstname': 'Oren',
#   'lastname': 'Treutel',
#   'email': 'rcrona@gmail.com',
#   'phone': '+3354825207400',
#   'birthday': '1972-01-26',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '79549 Guido Motorway',
#    'streetName': 'Sydnee Station',
#    'buildingNumber': '80237',
#    'city': 'New Virgieview',
#    'zipcode': '69956-4710',
#    'country': 'Saint Pierre and Miquelon',
#    'county_code': 'JE',
#    'latitude': 69.022901,
#    'longitude': -120.636931},
#   'website': 'http://runolfsson.org',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 13,
#   'firstname': 'Gordon',
#   'lastname': 'Hoppe',
#   'email': 'gideon23@keeling.com',
#   'phone': '+7725128754157',
#   'birthday': '2002-09-15',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '738 Will Fork Suite 333',
#    'streetName': 'Jose Valleys',
#    'buildingNumber': '3273',
#    'city': 'West Adelle',
#    'zipcode': '52779-8600',
#    'country': 'United Arab Emirates',
#    'county_code': 'HK',
#    'latitude': 72.502504,
#    'longitude': 44.551718},
#   'website': 'http://hartmann.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 14,
#   'firstname': 'Christ',
#   'lastname': 'Kautzer',
#   'email': 'klocko.leo@gmail.com',
#   'phone': '+9210656994770',
#   'birthday': '1940-11-12',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '287 Sanford Plains Apt. 148',
#    'streetName': 'Kitty Trafficway',
#    'buildingNumber': '49921',
#    'city': 'West Timothy',
#    'zipcode': '24273-9534',
#    'country': 'Eritrea',
#    'county_code': 'NG',
#    'latitude': 53.493893,
#    'longitude': -62.723332},
#   'website': 'http://schmeler.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 15,
#   'firstname': 'Eliseo',
#   'lastname': 'Auer',
#   'email': 'xhowe@block.net',
#   'phone': '+3220735101011',
#   'birthday': '1964-07-24',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '8419 Cletus Mission',
#    'streetName': 'Retta Lodge',
#    'buildingNumber': '613',
#    'city': 'New Kaylie',
#    'zipcode': '35758',
#    'country': 'Venezuela',
#    'county_code': 'TD',
#    'latitude': 72.135169,
#    'longitude': -81.576473},
#   'website': 'http://schiller.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 16,
#   'firstname': 'Darian',
#   'lastname': 'Jacobs',
#   'email': 'lakin.marianne@hotmail.com',
#   'phone': '+8956313645940',
#   'birthday': '1992-05-23',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '12483 Kuhlman Center',
#    'streetName': 'Pfeffer Knoll',
#    'buildingNumber': '8823',
#    'city': 'North Anibal',
#    'zipcode': '99573-8566',
#    'country': 'Macedonia',
#    'county_code': 'MX',
#    'latitude': -21.502256,
#    'longitude': -6.28173},
#   'website': 'http://wisozk.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 17,
#   'firstname': 'Charity',
#   'lastname': 'Toy',
#   'email': 'jermaine.pfannerstill@yahoo.com',
#   'phone': '+3104474957293',
#   'birthday': '1943-04-04',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '43768 Satterfield Tunnel Suite 024',
#    'streetName': 'Joanie Islands',
#    'buildingNumber': '39354',
#    'city': 'East Lavonnemouth',
#    'zipcode': '98475',
#    'country': 'Poland',
#    'county_code': 'GB',
#    'latitude': -52.170242,
#    'longitude': 171.560828},
#   'website': 'http://kerluke.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 18,
#   'firstname': 'Elsie',
#   'lastname': 'Satterfield',
#   'email': 'plangworth@breitenberg.com',
#   'phone': '+8230310083477',
#   'birthday': '1946-03-30',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '404 Herman Walks Apt. 135',
#    'streetName': 'Constantin Throughway',
#    'buildingNumber': '7618',
#    'city': 'Port Gradyhaven',
#    'zipcode': '93119',
#    'country': 'Northern Mariana Islands',
#    'county_code': 'AT',
#    'latitude': -86.754742,
#    'longitude': -137.220739},
#   'website': 'http://rodriguez.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 19,
#   'firstname': 'Maybell',
#   'lastname': 'Stoltenberg',
#   'email': 'ali.stokes@yahoo.com',
#   'phone': '+3908244290520',
#   'birthday': '1940-10-30',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '7045 Adams Oval',
#    'streetName': 'Flatley Cove',
#    'buildingNumber': '146',
#    'city': 'Considinehaven',
#    'zipcode': '84611-0834',
#    'country': 'Tunisia',
#    'county_code': 'SL',
#    'latitude': -66.70297,
#    'longitude': -91.938756},
#   'website': 'http://padberg.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 20,
#   'firstname': 'Angie',
#   'lastname': 'Miller',
#   'email': 'golden22@yahoo.com',
#   'phone': '+9866100755347',
#   'birthday': '1963-01-08',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '433 Nader Pass',
#    'streetName': 'Jordi Village',
#    'buildingNumber': '24517',
#    'city': 'Klockoberg',
#    'zipcode': '30975-5189',
#    'country': 'Macao',
#    'county_code': 'GG',
#    'latitude': -72.027409,
#    'longitude': -135.438949},
#   'website': 'http://balistreri.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 21,
#   'firstname': 'Aidan',
#   'lastname': 'Bruen',
#   'email': 'josianne05@gmail.com',
#   'phone': '+8608393573552',
#   'birthday': '1988-03-11',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '710 Connelly Glens',
#    'streetName': 'Hermann Square',
#    'buildingNumber': '86766',
#    'city': 'Baileymouth',
#    'zipcode': '55661-6775',
#    'country': 'Morocco',
#    'county_code': 'TM',
#    'latitude': -5.177669,
#    'longitude': 41.970844},
#   'website': 'http://effertz.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 22,
#   'firstname': 'Benjamin',
#   'lastname': 'Howe',
#   'email': 'gbogisich@morar.com',
#   'phone': '+8165782023067',
#   'birthday': '1981-09-20',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '227 Beverly Junctions Apt. 047',
#    'streetName': 'Gilberto Tunnel',
#    'buildingNumber': '138',
#    'city': 'North Gunnar',
#    'zipcode': '48852',
#    'country': 'Barbados',
#    'county_code': 'SK',
#    'latitude': -39.150035,
#    'longitude': 130.369801},
#   'website': 'http://koepp.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 23,
#   'firstname': 'Dillon',
#   'lastname': 'Wilkinson',
#   'email': 'payton.weissnat@cummerata.com',
#   'phone': '+7944255887082',
#   'birthday': '2014-05-10',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '7113 Felicita Meadow',
#    'streetName': 'Kohler Ranch',
#    'buildingNumber': '3706',
#    'city': 'Kilbackmouth',
#    'zipcode': '78900-4931',
#    'country': 'Tokelau',
#    'county_code': 'MZ',
#    'latitude': -78.854578,
#    'longitude': -28.20508},
#   'website': 'http://miller.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 24,
#   'firstname': 'Carolyne',
#   'lastname': 'Hahn',
#   'email': 'tprice@glover.com',
#   'phone': '+9720180018685',
#   'birthday': '1995-04-14',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '390 Bernhard Ville',
#    'streetName': 'Maggio Square',
#    'buildingNumber': '525',
#    'city': 'Lake Kadin',
#    'zipcode': '72006-0339',
#    'country': 'Gibraltar',
#    'county_code': 'AQ',
#    'latitude': -51.79173,
#    'longitude': 80.342469},
#   'website': 'http://bauch.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 25,
#   'firstname': 'Hilario',
#   'lastname': 'Reinger',
#   'email': 'sheldon56@rath.net',
#   'phone': '+8022061860213',
#   'birthday': '2009-02-08',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '673 Heller Green Suite 990',
#    'streetName': 'Dooley Island',
#    'buildingNumber': '58233',
#    'city': 'South Burnice',
#    'zipcode': '21668-8399',
#    'country': 'Sao Tome and Principe',
#    'county_code': 'CA',
#    'latitude': 0.288914,
#    'longitude': -27.216676},
#   'website': 'http://vonrueden.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 26,
#   'firstname': 'Tara',
#   'lastname': 'Schmeler',
#   'email': 'agerhold@grant.com',
#   'phone': '+4111066734517',
#   'birthday': '1950-03-27',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '7836 Marco Junctions',
#    'streetName': 'Zaria Wells',
#    'buildingNumber': '78802',
#    'city': 'Lake Nathan',
#    'zipcode': '61817',
#    'country': 'Colombia',
#    'county_code': 'AX',
#    'latitude': -67.57463,
#    'longitude': -58.680213},
#   'website': 'http://mills.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 27,
#   'firstname': 'Alanna',
#   'lastname': 'Kautzer',
#   'email': 'obailey@hotmail.com',
#   'phone': '+9968130102463',
#   'birthday': '1964-09-12',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '38652 Blanda Lights Apt. 267',
#    'streetName': 'Tomasa Points',
#    'buildingNumber': '54434',
#    'city': 'Lake Sylvia',
#    'zipcode': '18396',
#    'country': 'Haiti',
#    'county_code': 'PF',
#    'latitude': -8.648035,
#    'longitude': -171.255476},
#   'website': 'http://thompson.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 28,
#   'firstname': 'Carley',
#   'lastname': 'Mraz',
#   'email': 'shania05@turner.com',
#   'phone': '+4610793799276',
#   'birthday': '1969-08-07',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '29327 Maryam Creek Suite 003',
#    'streetName': "D'Amore Plaza",
#    'buildingNumber': '2700',
#    'city': 'Collinschester',
#    'zipcode': '49813',
#    'country': 'French Polynesia',
#    'county_code': 'CM',
#    'latitude': 81.474397,
#    'longitude': -132.593966},
#   'website': 'http://harber.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 29,
#   'firstname': 'Walker',
#   'lastname': 'Rolfson',
#   'email': 'andreanne36@kuhlman.com',
#   'phone': '+7685658076959',
#   'birthday': '1961-03-01',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '6104 Hilpert Trafficway Suite 070',
#    'streetName': 'Marlin Meadows',
#    'buildingNumber': '67741',
#    'city': 'Olechester',
#    'zipcode': '77805',
#    'country': 'United States Minor Outlying Islands',
#    'county_code': 'SC',
#    'latitude': 4.374757,
#    'longitude': -116.140766},
#   'website': 'http://welch.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 30,
#   'firstname': 'Holly',
#   'lastname': 'Moen',
#   'email': 'mjohns@jacobson.com',
#   'phone': '+4036152817237',
#   'birthday': '2004-06-07',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '22321 Lemke Rapids Apt. 828',
#    'streetName': 'Tiana Parkways',
#    'buildingNumber': '898',
#    'city': 'Port Jerrell',
#    'zipcode': '56355',
#    'country': 'Trinidad and Tobago',
#    'county_code': 'FO',
#    'latitude': 85.666595,
#    'longitude': -20.643711},
#   'website': 'http://mayer.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 31,
#   'firstname': 'Rebecca',
#   'lastname': 'Jenkins',
#   'email': 'alene17@bayer.org',
#   'phone': '+9935132312820',
#   'birthday': '1938-11-14',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '431 Pfannerstill Cove',
#    'streetName': 'Della Fork',
#    'buildingNumber': '4883',
#    'city': 'Okunevashire',
#    'zipcode': '76482-4044',
#    'country': 'Panama',
#    'county_code': 'HK',
#    'latitude': 57.571026,
#    'longitude': 60.741469},
#   'website': 'http://hermiston.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 32,
#   'firstname': 'Novella',
#   'lastname': 'Friesen',
#   'email': 'salvador17@rosenbaum.org',
#   'phone': '+9072912941568',
#   'birthday': '1935-09-26',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '213 Auer Burg',
#    'streetName': 'Beahan Pine',
#    'buildingNumber': '355',
#    'city': 'Lehnerview',
#    'zipcode': '57447',
#    'country': 'Slovakia (Slovak Republic)',
#    'county_code': 'MO',
#    'latitude': -39.877466,
#    'longitude': 32.725894},
#   'website': 'http://leannon.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 33,
#   'firstname': 'Dulce',
#   'lastname': 'Jakubowski',
#   'email': 'titus76@yahoo.com',
#   'phone': '+5917819919507',
#   'birthday': '1999-11-05',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '1146 Hauck Union Apt. 554',
#    'streetName': 'Norberto Forge',
#    'buildingNumber': '41663',
#    'city': 'Tillmanport',
#    'zipcode': '93621-5265',
#    'country': 'Ecuador',
#    'county_code': 'CK',
#    'latitude': -7.271846,
#    'longitude': -123.562879},
#   'website': 'http://torp.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 34,
#   'firstname': 'Melyna',
#   'lastname': 'Kuhic',
#   'email': 'dereck.kreiger@ferry.info',
#   'phone': '+2190294717405',
#   'birthday': '2004-06-28',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '2214 Mustafa Route Apt. 565',
#    'streetName': 'Kolby Divide',
#    'buildingNumber': '169',
#    'city': 'Wolfport',
#    'zipcode': '10195-2581',
#    'country': 'Reunion',
#    'county_code': 'ME',
#    'latitude': -58.044534,
#    'longitude': -170.596777},
#   'website': 'http://heller.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 35,
#   'firstname': 'Mariela',
#   'lastname': 'Daniel',
#   'email': 'pansy46@heidenreich.net',
#   'phone': '+4619233673863',
#   'birthday': '1995-06-09',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '9493 Hazle Fort',
#    'streetName': 'Casper Lodge',
#    'buildingNumber': '385',
#    'city': 'North Phyllis',
#    'zipcode': '88145',
#    'country': 'Mayotte',
#    'county_code': 'LC',
#    'latitude': 1.846386,
#    'longitude': -170.204425},
#   'website': 'http://kutch.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 36,
#   'firstname': 'Bradley',
#   'lastname': 'Considine',
#   'email': 'stevie.funk@hotmail.com',
#   'phone': '+7441026145326',
#   'birthday': '1967-10-22',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '639 White Plains',
#    'streetName': 'Jones Tunnel',
#    'buildingNumber': '8840',
#    'city': 'Altenwerthfort',
#    'zipcode': '38073',
#    'country': 'Maldives',
#    'county_code': 'FK',
#    'latitude': -66.191434,
#    'longitude': 80.192528},
#   'website': 'http://corwin.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 37,
#   'firstname': 'Angelita',
#   'lastname': 'Nitzsche',
#   'email': 'sofia.maggio@zieme.org',
#   'phone': '+3954759869040',
#   'birthday': '1950-01-04',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '740 Dibbert Motorway',
#    'streetName': 'Bosco Springs',
#    'buildingNumber': '843',
#    'city': 'New Elvie',
#    'zipcode': '07590-3265',
#    'country': 'Lithuania',
#    'county_code': 'VE',
#    'latitude': 25.787513,
#    'longitude': 44.064616},
#   'website': 'http://mueller.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 38,
#   'firstname': 'Imogene',
#   'lastname': 'Hauck',
#   'email': 'oroob@hotmail.com',
#   'phone': '+6381555384767',
#   'birthday': '1976-12-07',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '29536 Marielle Plain Apt. 119',
#    'streetName': 'Greenfelder Forest',
#    'buildingNumber': '7041',
#    'city': 'South Coytown',
#    'zipcode': '77095-3033',
#    'country': 'Mexico',
#    'county_code': 'IE',
#    'latitude': 74.065458,
#    'longitude': 14.056196},
#   'website': 'http://bernier.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 39,
#   'firstname': 'Zoie',
#   'lastname': 'Harber',
#   'email': 'gislason.mara@hotmail.com',
#   'phone': '+4082117938193',
#   'birthday': '2001-11-18',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '43975 Ryan Way',
#    'streetName': 'Bessie Run',
#    'buildingNumber': '82845',
#    'city': 'Lake Elainaberg',
#    'zipcode': '64567-9654',
#    'country': 'Taiwan',
#    'county_code': 'FI',
#    'latitude': 85.506371,
#    'longitude': 32.529823},
#   'website': 'http://trantow.net',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 40,
#   'firstname': 'Marlon',
#   'lastname': 'Hudson',
#   'email': 'slowe@yahoo.com',
#   'phone': '+7873877685657',
#   'birthday': '2016-02-13',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '4059 Turner Lane Apt. 954',
#    'streetName': 'Leonora Village',
#    'buildingNumber': '6357',
#    'city': 'Ovaland',
#    'zipcode': '95735',
#    'country': 'Belize',
#    'county_code': 'QA',
#    'latitude': -86.661631,
#    'longitude': -148.80322},
#   'website': 'http://schaden.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 41,
#   'firstname': 'Greyson',
#   'lastname': 'Labadie',
#   'email': 'lebsack.talia@gutmann.com',
#   'phone': '+1365590446945',
#   'birthday': '1945-05-04',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '616 Okuneva Walk',
#    'streetName': 'Victoria Wall',
#    'buildingNumber': '5713',
#    'city': 'Grahamfurt',
#    'zipcode': '47795-3557',
#    'country': 'Saint Kitts and Nevis',
#    'county_code': 'PH',
#    'latitude': 13.032728,
#    'longitude': 137.893433},
#   'website': 'http://romaguera.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 42,
#   'firstname': 'Elody',
#   'lastname': 'Abshire',
#   'email': 'rtorphy@yahoo.com',
#   'phone': '+9517812328359',
#   'birthday': '1981-10-05',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '30600 Baumbach Station Suite 353',
#    'streetName': 'McDermott Mountains',
#    'buildingNumber': '3813',
#    'city': 'Emmetport',
#    'zipcode': '28988-9756',
#    'country': 'Saint Martin',
#    'county_code': 'BB',
#    'latitude': -14.766252,
#    'longitude': 100.08556},
#   'website': 'http://ullrich.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 43,
#   'firstname': 'Marjolaine',
#   'lastname': 'Leffler',
#   'email': 'danial19@hotmail.com',
#   'phone': '+3059453677872',
#   'birthday': '1958-03-08',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '408 Dibbert Branch Apt. 007',
#    'streetName': 'Tate Dam',
#    'buildingNumber': '44036',
#    'city': 'Erwintown',
#    'zipcode': '93485',
#    'country': 'Reunion',
#    'county_code': 'DE',
#    'latitude': -86.415144,
#    'longitude': -178.458076},
#   'website': 'http://maggio.net',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 44,
#   'firstname': 'Jack',
#   'lastname': 'Nikolaus',
#   'email': 'myah.ledner@stark.info',
#   'phone': '+5754763030689',
#   'birthday': '1951-04-09',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '7275 Dexter Square',
#    'streetName': 'Greenfelder Way',
#    'buildingNumber': '7787',
#    'city': 'East Jasminton',
#    'zipcode': '39063',
#    'country': 'India',
#    'county_code': 'DO',
#    'latitude': -4.119298,
#    'longitude': -162.148961},
#   'website': 'http://fadel.org',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 45,
#   'firstname': 'Nannie',
#   'lastname': 'Bauch',
#   'email': 'nwaelchi@abshire.com',
#   'phone': '+6309450248526',
#   'birthday': '1987-02-23',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '87998 Marshall Square Suite 065',
#    'streetName': 'Walsh Fields',
#    'buildingNumber': '7781',
#    'city': 'Shanellemouth',
#    'zipcode': '49101',
#    'country': 'Netherlands Antilles',
#    'county_code': 'QA',
#    'latitude': 29.899846,
#    'longitude': -2.785573},
#   'website': 'http://hartmann.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 46,
#   'firstname': 'Freddy',
#   'lastname': 'Pollich',
#   'email': 'guillermo17@lindgren.net',
#   'phone': '+7503554815402',
#   'birthday': '1992-05-12',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '8149 Eliza Ramp Apt. 628',
#    'streetName': 'Naomi Streets',
#    'buildingNumber': '6036',
#    'city': 'Williamsonmouth',
#    'zipcode': '83025',
#    'country': 'Jersey',
#    'county_code': 'SK',
#    'latitude': 49.690439,
#    'longitude': -125.101523},
#   'website': 'http://kertzmann.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 47,
#   'firstname': 'Rick',
#   'lastname': 'Lynch',
#   'email': 'evandervort@keeling.org',
#   'phone': '+7980695090380',
#   'birthday': '2005-03-05',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '7687 Roberts Drive',
#    'streetName': 'Willms Road',
#    'buildingNumber': '93974',
#    'city': 'Beahanhaven',
#    'zipcode': '03104-8267',
#    'country': 'Cocos (Keeling) Islands',
#    'county_code': 'CO',
#    'latitude': 16.550011,
#    'longitude': -59.777908},
#   'website': 'http://schowalter.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 48,
#   'firstname': 'Christine',
#   'lastname': 'Langosh',
#   'email': 'stephany18@hotmail.com',
#   'phone': '+9239462272718',
#   'birthday': '1978-01-13',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '70602 Rosenbaum Village Suite 498',
#    'streetName': 'Kutch Skyway',
#    'buildingNumber': '6399',
#    'city': 'Miguelport',
#    'zipcode': '95177-2808',
#    'country': 'Chad',
#    'county_code': 'BQ',
#    'latitude': -80.907376,
#    'longitude': -36.018167},
#   'website': 'http://blanda.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 49,
#   'firstname': 'Elijah',
#   'lastname': 'Davis',
#   'email': 'beatty.eldon@gmail.com',
#   'phone': '+4374423130316',
#   'birthday': '1950-06-06',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '2331 Moises Haven Suite 983',
#    'streetName': 'Cummerata Creek',
#    'buildingNumber': '239',
#    'city': 'South Kristyfort',
#    'zipcode': '45900',
#    'country': 'Uruguay',
#    'county_code': 'CL',
#    'latitude': 56.972034,
#    'longitude': 51.869297},
#   'website': 'http://volkman.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 50,
#   'firstname': 'Rudy',
#   'lastname': 'Goodwin',
#   'email': 'ngreenfelder@harvey.info',
#   'phone': '+3252948997486',
#   'birthday': '1952-11-21',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '521 Eula Key',
#    'streetName': 'Conroy Village',
#    'buildingNumber': '7451',
#    'city': 'Ezequielhaven',
#    'zipcode': '24278-9820',
#    'country': 'Nicaragua',
#    'county_code': 'PY',
#    'latitude': 81.955368,
#    'longitude': -111.19203},
#   'website': 'http://mccullough.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 51,
#   'firstname': 'Valentine',
#   'lastname': 'Krajcik',
#   'email': 'lelah93@kling.com',
#   'phone': '+9792894228991',
#   'birthday': '1939-03-29',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '718 Paige Mountains',
#    'streetName': 'Gulgowski Ridge',
#    'buildingNumber': '677',
#    'city': 'East Anahi',
#    'zipcode': '63052-0640',
#    'country': 'Afghanistan',
#    'county_code': 'JP',
#    'latitude': 68.072949,
#    'longitude': -114.364371},
#   'website': 'http://rempel.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 52,
#   'firstname': 'Kaia',
#   'lastname': 'Abshire',
#   'email': 'iliana40@cronin.com',
#   'phone': '+7432992156056',
#   'birthday': '2019-06-25',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '736 Alan Crescent',
#    'streetName': 'Ortiz Corners',
#    'buildingNumber': '2480',
#    'city': 'Danykafurt',
#    'zipcode': '66415',
#    'country': 'Turkmenistan',
#    'county_code': 'SM',
#    'latitude': 13.837805,
#    'longitude': -18.203102},
#   'website': 'http://swift.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 53,
#   'firstname': 'Cristina',
#   'lastname': 'Nikolaus',
#   'email': 'trudie.greenfelder@moore.com',
#   'phone': '+5222293971917',
#   'birthday': '2021-08-03',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '5997 Marina Port Apt. 545',
#    'streetName': 'Wisoky Avenue',
#    'buildingNumber': '5160',
#    'city': 'Tiffanyfurt',
#    'zipcode': '35781-0627',
#    'country': 'Martinique',
#    'county_code': 'SJ',
#    'latitude': -36.785139,
#    'longitude': 81.215088},
#   'website': 'http://fay.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 54,
#   'firstname': 'Pink',
#   'lastname': 'Rippin',
#   'email': 'jevon.west@mohr.com',
#   'phone': '+8578934891619',
#   'birthday': '1979-06-04',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '698 Parisian Circles',
#    'streetName': 'Jast Tunnel',
#    'buildingNumber': '49504',
#    'city': 'West Robb',
#    'zipcode': '99495',
#    'country': 'Saint Barthelemy',
#    'county_code': 'CW',
#    'latitude': -37.081065,
#    'longitude': 68.526357},
#   'website': 'http://senger.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 55,
#   'firstname': 'Elijah',
#   'lastname': 'Collier',
#   'email': 'friesen.jo@bernier.com',
#   'phone': '+5434494438779',
#   'birthday': '1981-11-09',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '8562 Nelda Motorway Apt. 913',
#    'streetName': 'Williamson Trail',
#    'buildingNumber': '914',
#    'city': 'East Carmen',
#    'zipcode': '28876',
#    'country': 'Greenland',
#    'county_code': 'HK',
#    'latitude': 50.454055,
#    'longitude': -8.145004},
#   'website': 'http://hoppe.net',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 56,
#   'firstname': 'Ellen',
#   'lastname': 'Kling',
#   'email': 'dickinson.german@yahoo.com',
#   'phone': '+5879917168090',
#   'birthday': '2012-02-19',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '7323 Asha Junction Suite 331',
#    'streetName': 'Lon Grove',
#    'buildingNumber': '346',
#    'city': 'East Tanner',
#    'zipcode': '27040',
#    'country': 'Thailand',
#    'county_code': 'WS',
#    'latitude': -68.221913,
#    'longitude': 149.372816},
#   'website': 'http://wolff.net',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 57,
#   'firstname': 'Jaycee',
#   'lastname': 'Hackett',
#   'email': 'torphy.carlee@hammes.biz',
#   'phone': '+8453081817782',
#   'birthday': '2005-07-18',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': "739 O'Hara Ways Suite 339",
#    'streetName': 'Upton Point',
#    'buildingNumber': '83146',
#    'city': 'Janiceport',
#    'zipcode': '34578-6825',
#    'country': 'Poland',
#    'county_code': 'ML',
#    'latitude': 65.210664,
#    'longitude': -24.872753},
#   'website': 'http://harvey.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 58,
#   'firstname': 'Fausto',
#   'lastname': 'Olson',
#   'email': 'goldner.colin@yahoo.com',
#   'phone': '+8048469268921',
#   'birthday': '2012-11-20',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '8858 Madelynn Tunnel',
#    'streetName': 'Denesik Club',
#    'buildingNumber': '9630',
#    'city': 'Ethaland',
#    'zipcode': '54401',
#    'country': 'Sierra Leone',
#    'county_code': 'GP',
#    'latitude': 44.928178,
#    'longitude': -147.605448},
#   'website': 'http://koch.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 59,
#   'firstname': 'Millie',
#   'lastname': 'Connelly',
#   'email': 'borer.llewellyn@hotmail.com',
#   'phone': '+2998299060287',
#   'birthday': '1981-06-23',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '5928 Antoinette Village',
#    'streetName': 'Ullrich Islands',
#    'buildingNumber': '59079',
#    'city': 'North Curt',
#    'zipcode': '09736-5498',
#    'country': 'Tuvalu',
#    'county_code': 'PY',
#    'latitude': 51.131877,
#    'longitude': 150.944053},
#   'website': 'http://bashirian.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 60,
#   'firstname': 'Britney',
#   'lastname': 'Kunze',
#   'email': 'maximillia86@goodwin.info',
#   'phone': '+1851437372365',
#   'birthday': '2014-10-30',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '46610 Cydney Ports Apt. 670',
#    'streetName': 'Yvonne Centers',
#    'buildingNumber': '4360',
#    'city': 'West Vernstad',
#    'zipcode': '00081-2280',
#    'country': 'Bahrain',
#    'county_code': 'MG',
#    'latitude': 48.768654,
#    'longitude': 91.794025},
#   'website': 'http://klein.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 61,
#   'firstname': 'Rebeca',
#   'lastname': 'Denesik',
#   'email': 'america53@hotmail.com',
#   'phone': '+4810282432476',
#   'birthday': '1936-10-10',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '831 Modesto Pines',
#    'streetName': 'Ignatius Isle',
#    'buildingNumber': '1482',
#    'city': 'Johnsville',
#    'zipcode': '36338',
#    'country': 'Reunion',
#    'county_code': 'MS',
#    'latitude': -32.058339,
#    'longitude': 152.782575},
#   'website': 'http://vandervort.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 62,
#   'firstname': 'Jaiden',
#   'lastname': 'Rodriguez',
#   'email': 'hharber@bergstrom.org',
#   'phone': '+5676915137672',
#   'birthday': '1972-07-30',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '95055 Sawayn Trail Suite 007',
#    'streetName': 'Jackie Mountain',
#    'buildingNumber': '233',
#    'city': 'Margueriteberg',
#    'zipcode': '02987',
#    'country': 'Germany',
#    'county_code': 'MQ',
#    'latitude': 23.490212,
#    'longitude': -89.543545},
#   'website': 'http://moen.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 63,
#   'firstname': 'Kathlyn',
#   'lastname': 'Bednar',
#   'email': 'jstark@feeney.com',
#   'phone': '+6837140248475',
#   'birthday': '1984-10-03',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '2672 Jordan Street',
#    'streetName': 'Haag Shores',
#    'buildingNumber': '40631',
#    'city': 'East Eunice',
#    'zipcode': '37422-1492',
#    'country': 'Bosnia and Herzegovina',
#    'county_code': 'PT',
#    'latitude': 62.696564,
#    'longitude': 179.879783},
#   'website': 'http://connelly.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 64,
#   'firstname': 'Leonora',
#   'lastname': 'Bailey',
#   'email': 'mccullough.ronny@legros.com',
#   'phone': '+2805456480044',
#   'birthday': '2010-01-08',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '199 Dibbert Roads Suite 384',
#    'streetName': 'Gulgowski Center',
#    'buildingNumber': '910',
#    'city': 'Moniqueside',
#    'zipcode': '42722',
#    'country': 'Andorra',
#    'county_code': 'MX',
#    'latitude': 26.100242,
#    'longitude': -81.619704},
#   'website': 'http://jones.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 65,
#   'firstname': 'Lizeth',
#   'lastname': 'Kerluke',
#   'email': 'mpredovic@hegmann.com',
#   'phone': '+7699768620120',
#   'birthday': '2014-10-31',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '701 Schimmel Fall Apt. 399',
#    'streetName': 'Alfonzo Lodge',
#    'buildingNumber': '707',
#    'city': 'West Wallaceborough',
#    'zipcode': '08364',
#    'country': 'Papua New Guinea',
#    'county_code': 'BG',
#    'latitude': 58.136812,
#    'longitude': -141.062245},
#   'website': 'http://weber.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 66,
#   'firstname': 'Felicita',
#   'lastname': 'Denesik',
#   'email': 'ostanton@grady.com',
#   'phone': '+1318247304548',
#   'birthday': '2022-12-09',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '76447 Jordyn Flats Apt. 335',
#    'streetName': 'Vita Fields',
#    'buildingNumber': '72141',
#    'city': 'South Zula',
#    'zipcode': '46221',
#    'country': 'Rwanda',
#    'county_code': 'MH',
#    'latitude': -83.58685,
#    'longitude': -126.348288},
#   'website': 'http://morar.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 67,
#   'firstname': 'Candice',
#   'lastname': 'Nitzsche',
#   'email': 'jerde.kayli@hotmail.com',
#   'phone': '+8159848587729',
#   'birthday': '1934-06-04',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '356 Alena Summit',
#    'streetName': 'Roosevelt Gateway',
#    'buildingNumber': '376',
#    'city': 'Cheyenneview',
#    'zipcode': '80957-3054',
#    'country': 'Kenya',
#    'county_code': 'GE',
#    'latitude': 88.374815,
#    'longitude': 153.589248},
#   'website': 'http://wuckert.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 68,
#   'firstname': 'Sadie',
#   'lastname': 'Satterfield',
#   'email': 'casper.adele@yahoo.com',
#   'phone': '+6466338453262',
#   'birthday': '1936-01-07',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '22863 William Turnpike Suite 638',
#    'streetName': 'Dessie Oval',
#    'buildingNumber': '12549',
#    'city': 'Fadelton',
#    'zipcode': '30934-7736',
#    'country': 'United States Minor Outlying Islands',
#    'county_code': 'KN',
#    'latitude': -61.217596,
#    'longitude': -138.830573},
#   'website': 'http://lesch.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 69,
#   'firstname': 'Meredith',
#   'lastname': 'Kling',
#   'email': 'candida43@hotmail.com',
#   'phone': '+4051537351738',
#   'birthday': '1958-01-25',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '82490 Senger Walks Apt. 245',
#    'streetName': 'Stanton Prairie',
#    'buildingNumber': '400',
#    'city': 'West Selmerstad',
#    'zipcode': '92140-2991',
#    'country': 'Lesotho',
#    'county_code': 'VC',
#    'latitude': 1.422991,
#    'longitude': -97.379072},
#   'website': 'http://west.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 70,
#   'firstname': 'Jaunita',
#   'lastname': 'Stracke',
#   'email': 'blanda.rae@yahoo.com',
#   'phone': '+1643168657811',
#   'birthday': '1994-03-02',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '61516 Turner Camp',
#    'streetName': 'Lindsey Ville',
#    'buildingNumber': '27068',
#    'city': 'South Ismael',
#    'zipcode': '70748-7464',
#    'country': 'Faroe Islands',
#    'county_code': 'MD',
#    'latitude': 30.939456,
#    'longitude': -12.759738},
#   'website': 'http://cartwright.net',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 71,
#   'firstname': 'Mariah',
#   'lastname': 'Williamson',
#   'email': 'brandi.zemlak@swaniawski.com',
#   'phone': '+1449097022934',
#   'birthday': '1936-01-26',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '91506 Mills Rapid',
#    'streetName': 'Warren Orchard',
#    'buildingNumber': '426',
#    'city': 'Glovershire',
#    'zipcode': '35519',
#    'country': 'Yemen',
#    'county_code': 'DJ',
#    'latitude': -77.624039,
#    'longitude': -156.057445},
#   'website': 'http://tremblay.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 72,
#   'firstname': 'Dee',
#   'lastname': 'Luettgen',
#   'email': 'halle71@schroeder.com',
#   'phone': '+7321170759947',
#   'birthday': '2007-05-10',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '73988 Tillman Circle',
#    'streetName': 'Luz Valleys',
#    'buildingNumber': '861',
#    'city': 'Thaliaside',
#    'zipcode': '10722',
#    'country': 'Saudi Arabia',
#    'county_code': 'TT',
#    'latitude': 42.534464,
#    'longitude': 122.915328},
#   'website': 'http://lubowitz.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 73,
#   'firstname': 'Dylan',
#   'lastname': 'Grady',
#   'email': 'vreinger@gmail.com',
#   'phone': '+1923840521470',
#   'birthday': '1997-11-11',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '969 Barrows Mountain Suite 295',
#    'streetName': 'Hayes Circle',
#    'buildingNumber': '92062',
#    'city': 'East Cesarside',
#    'zipcode': '90393',
#    'country': 'El Salvador',
#    'county_code': 'BT',
#    'latitude': 62.629378,
#    'longitude': 178.816732},
#   'website': 'http://hills.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 74,
#   'firstname': 'Faye',
#   'lastname': 'Bailey',
#   'email': 'uebert@sipes.net',
#   'phone': '+9535303428970',
#   'birthday': '1942-10-17',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '49769 Pearlie Land',
#    'streetName': 'Lexi Corner',
#    'buildingNumber': '2592',
#    'city': 'Wilfordfort',
#    'zipcode': '52357-1400',
#    'country': 'Oman',
#    'county_code': 'AS',
#    'latitude': 4.258901,
#    'longitude': -3.380813},
#   'website': 'http://schultz.org',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 75,
#   'firstname': 'Johnny',
#   'lastname': 'Yost',
#   'email': 'sonya03@deckow.com',
#   'phone': '+9046784936337',
#   'birthday': '1955-05-05',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '267 Murphy Route',
#    'streetName': 'Erling Circle',
#    'buildingNumber': '439',
#    'city': 'Armstrongchester',
#    'zipcode': '50404-7799',
#    'country': 'Colombia',
#    'county_code': 'TW',
#    'latitude': 75.986904,
#    'longitude': -45.356739},
#   'website': 'http://buckridge.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 76,
#   'firstname': 'Lilliana',
#   'lastname': 'Kemmer',
#   'email': 'osinski.destini@yahoo.com',
#   'phone': '+2680732856814',
#   'birthday': '2019-11-23',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '15124 Rupert Cape',
#    'streetName': 'Moshe Lake',
#    'buildingNumber': '220',
#    'city': 'Port Valentinland',
#    'zipcode': '54379',
#    'country': 'Nauru',
#    'county_code': 'IT',
#    'latitude': -27.523737,
#    'longitude': -147.692973},
#   'website': 'http://labadie.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 77,
#   'firstname': 'Dora',
#   'lastname': 'Raynor',
#   'email': 'melyna.corwin@legros.com',
#   'phone': '+3346415694752',
#   'birthday': '1982-09-24',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '1400 Kutch Skyway Suite 816',
#    'streetName': 'Schulist View',
#    'buildingNumber': '9853',
#    'city': 'East Vivien',
#    'zipcode': '58188',
#    'country': 'Oman',
#    'county_code': 'MT',
#    'latitude': 72.167257,
#    'longitude': -40.369755},
#   'website': 'http://hessel.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 78,
#   'firstname': 'Darion',
#   'lastname': 'Rohan',
#   'email': 'asa.barrows@blick.net',
#   'phone': '+3877276368856',
#   'birthday': '2005-07-27',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '89142 Boyle Trafficway Suite 166',
#    'streetName': 'Emerald Pass',
#    'buildingNumber': '49008',
#    'city': 'Alvinamouth',
#    'zipcode': '62179-0761',
#    'country': 'Jersey',
#    'county_code': 'CH',
#    'latitude': -8.466485,
#    'longitude': 154.255737},
#   'website': 'http://gleason.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 79,
#   'firstname': 'Desiree',
#   'lastname': 'Mayert',
#   'email': 'carroll.antonietta@hotmail.com',
#   'phone': '+8518697186141',
#   'birthday': '1995-10-07',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '7897 Verda Circles',
#    'streetName': 'Wilbert Expressway',
#    'buildingNumber': '597',
#    'city': 'New Shea',
#    'zipcode': '53101',
#    'country': 'Cambodia',
#    'county_code': 'BR',
#    'latitude': 78.828571,
#    'longitude': 126.360474},
#   'website': 'http://tremblay.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 80,
#   'firstname': 'Martina',
#   'lastname': 'Runolfsson',
#   'email': 'kuhlman.adelle@hintz.com',
#   'phone': '+3814586413788',
#   'birthday': '1947-09-04',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '36682 Schamberger Throughway Apt. 044',
#    'streetName': 'Quitzon Hill',
#    'buildingNumber': '18153',
#    'city': 'Kreigerview',
#    'zipcode': '93841',
#    'country': 'Montenegro',
#    'county_code': 'QA',
#    'latitude': -13.971733,
#    'longitude': 159.972962},
#   'website': 'http://mitchell.net',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 81,
#   'firstname': 'Donald',
#   'lastname': 'Wintheiser',
#   'email': 'ronaldo.kilback@damore.com',
#   'phone': '+4188559740372',
#   'birthday': '2011-02-25',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '800 Sally Vista',
#    'streetName': 'Alisha Ridge',
#    'buildingNumber': '16558',
#    'city': 'New Tamaraton',
#    'zipcode': '18004',
#    'country': 'Macao',
#    'county_code': 'RE',
#    'latitude': 26.889769,
#    'longitude': -160.723671},
#   'website': 'http://cartwright.org',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 82,
#   'firstname': 'Webster',
#   'lastname': 'Kerluke',
#   'email': 'evalyn72@cole.com',
#   'phone': '+1662076961111',
#   'birthday': '1987-12-27',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '45324 Prohaska Stream Apt. 660',
#    'streetName': 'Funk Estate',
#    'buildingNumber': '5278',
#    'city': 'Emmerichstad',
#    'zipcode': '33150-3961',
#    'country': 'American Samoa',
#    'county_code': 'TV',
#    'latitude': 73.391775,
#    'longitude': -160.154986},
#   'website': 'http://schuster.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 83,
#   'firstname': 'Karlee',
#   'lastname': 'Bartoletti',
#   'email': 'kozey.bethel@bruen.info',
#   'phone': '+4482985016341',
#   'birthday': '2023-06-30',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '214 Tabitha Inlet Apt. 071',
#    'streetName': 'Tristian Crest',
#    'buildingNumber': '192',
#    'city': 'Wittingfort',
#    'zipcode': '77806-6626',
#    'country': 'Korea',
#    'county_code': 'BD',
#    'latitude': -38.34791,
#    'longitude': 110.826365},
#   'website': 'http://rath.net',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 84,
#   'firstname': 'Max',
#   'lastname': 'Mosciski',
#   'email': 'missouri.fadel@yahoo.com',
#   'phone': '+1663562974595',
#   'birthday': '1952-07-06',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '8248 Ned Mews Apt. 373',
#    'streetName': 'Jerome View',
#    'buildingNumber': '9947',
#    'city': 'North Lempimouth',
#    'zipcode': '35653',
#    'country': 'Portugal',
#    'county_code': 'CW',
#    'latitude': -87.187096,
#    'longitude': 178.386219},
#   'website': 'http://hahn.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 85,
#   'firstname': 'Christelle',
#   'lastname': 'Blick',
#   'email': 'frice@yahoo.com',
#   'phone': '+3746318432109',
#   'birthday': '1994-02-13',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '894 Brekke Vista',
#    'streetName': 'Jeremie Junctions',
#    'buildingNumber': '10068',
#    'city': 'North Reyesfort',
#    'zipcode': '87869-5826',
#    'country': 'Spain',
#    'county_code': 'TJ',
#    'latitude': -10.210594,
#    'longitude': 83.976489},
#   'website': 'http://konopelski.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 86,
#   'firstname': 'Reggie',
#   'lastname': 'Keeling',
#   'email': 'kovacek.casey@hettinger.info',
#   'phone': '+8561082471553',
#   'birthday': '2016-07-20',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '434 Kshlerin Coves',
#    'streetName': 'Jared Greens',
#    'buildingNumber': '9865',
#    'city': 'Santosland',
#    'zipcode': '67907-2090',
#    'country': 'Zambia',
#    'county_code': 'MG',
#    'latitude': -19.656412,
#    'longitude': 77.669543},
#   'website': 'http://waters.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 87,
#   'firstname': 'Thurman',
#   'lastname': 'Stoltenberg',
#   'email': 'greyson61@ward.com',
#   'phone': '+2650499464287',
#   'birthday': '1957-01-11',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '515 Domenico Via',
#    'streetName': 'Shaylee Haven',
#    'buildingNumber': '100',
#    'city': 'Larkinland',
#    'zipcode': '64651-1103',
#    'country': 'Sri Lanka',
#    'county_code': 'YT',
#    'latitude': 5.631682,
#    'longitude': -70.228187},
#   'website': 'http://brown.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 88,
#   'firstname': 'Muriel',
#   'lastname': 'Kilback',
#   'email': 'jaquan.williamson@kirlin.net',
#   'phone': '+7866084016644',
#   'birthday': '1997-10-19',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '81409 Regan Heights Apt. 955',
#    'streetName': 'Stephanie Islands',
#    'buildingNumber': '118',
#    'city': 'Port Orie',
#    'zipcode': '01431',
#    'country': 'Belarus',
#    'county_code': 'MW',
#    'latitude': 78.159417,
#    'longitude': -172.388875},
#   'website': 'http://kreiger.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 89,
#   'firstname': 'Clement',
#   'lastname': 'Lubowitz',
#   'email': 'ziemann.rusty@crona.com',
#   'phone': '+5924030761117',
#   'birthday': '1979-01-14',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '76367 Lois Avenue',
#    'streetName': 'Simeon Landing',
#    'buildingNumber': '66187',
#    'city': 'Port Darion',
#    'zipcode': '82350',
#    'country': 'Bosnia and Herzegovina',
#    'county_code': 'UG',
#    'latitude': -4.876719,
#    'longitude': -46.553685},
#   'website': 'http://gusikowski.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 90,
#   'firstname': 'Stephon',
#   'lastname': 'Murray',
#   'email': 'tremblay.sammy@stamm.com',
#   'phone': '+4777734988253',
#   'birthday': '1964-06-27',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '7276 Legros Trail Suite 421',
#    'streetName': 'Darrion Land',
#    'buildingNumber': '8580',
#    'city': 'Robinmouth',
#    'zipcode': '15802',
#    'country': 'Cameroon',
#    'county_code': 'ST',
#    'latitude': -34.798394,
#    'longitude': 39.781432},
#   'website': 'http://rogahn.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 91,
#   'firstname': 'Erna',
#   'lastname': 'Wintheiser',
#   'email': 'feeney.zetta@pacocha.net',
#   'phone': '+6537449099722',
#   'birthday': '2000-06-26',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '944 Rohan Wall Suite 863',
#    'streetName': 'Hassie Mills',
#    'buildingNumber': '126',
#    'city': 'Dibberttown',
#    'zipcode': '02678',
#    'country': 'Burkina Faso',
#    'county_code': 'VG',
#    'latitude': -20.429657,
#    'longitude': -50.630766},
#   'website': 'http://maggio.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 92,
#   'firstname': 'Ellis',
#   'lastname': 'Kiehn',
#   'email': 'alaina.rippin@gmail.com',
#   'phone': '+3017875728378',
#   'birthday': '1976-09-24',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '4442 Trisha Ville Suite 393',
#    'streetName': 'Salma Street',
#    'buildingNumber': '155',
#    'city': 'Cummingshaven',
#    'zipcode': '35392',
#    'country': 'Aruba',
#    'county_code': 'CL',
#    'latitude': -44.726408,
#    'longitude': -37.161313},
#   'website': 'http://howe.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 93,
#   'firstname': 'Lyda',
#   'lastname': 'Deckow',
#   'email': 'elna04@hotmail.com',
#   'phone': '+8095772657786',
#   'birthday': '1967-09-11',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '688 Torphy Dam',
#    'streetName': 'Sigurd Union',
#    'buildingNumber': '344',
#    'city': 'Lake Santiago',
#    'zipcode': '17991',
#    'country': 'Malawi',
#    'county_code': 'CI',
#    'latitude': 51.151505,
#    'longitude': -122.817024},
#   'website': 'http://damore.org',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 94,
#   'firstname': 'Earnestine',
#   'lastname': 'Bergnaum',
#   'email': 'hreilly@gmail.com',
#   'phone': '+6280231660227',
#   'birthday': '1963-04-25',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '217 Mekhi Street',
#    'streetName': 'Pacocha Groves',
#    'buildingNumber': '151',
#    'city': 'West Dianaport',
#    'zipcode': '17736',
#    'country': 'Saint Lucia',
#    'county_code': 'MV',
#    'latitude': 28.882562,
#    'longitude': -133.875477},
#   'website': 'http://effertz.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 95,
#   'firstname': 'Nicholaus',
#   'lastname': 'Grady',
#   'email': 'fahey.mary@roberts.com',
#   'phone': '+7156383011018',
#   'birthday': '2023-02-06',
#   'gender': 'male',
#   'address': {'id': 0,
#    'street': '8692 Bernadine Dam',
#    'streetName': 'Goldner Court',
#    'buildingNumber': '1695',
#    'city': 'Darrinton',
#    'zipcode': '48142-6872',
#    'country': 'Mozambique',
#    'county_code': 'TV',
#    'latitude': -11.201195,
#    'longitude': -58.217321},
#   'website': 'http://yost.info',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 96,
#   'firstname': 'Lucile',
#   'lastname': 'Prosacco',
#   'email': 'kulas.jewell@koepp.com',
#   'phone': '+1675175718859',
#   'birthday': '1951-11-09',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '88791 Frederic Crescent Apt. 477',
#    'streetName': 'Raymond Road',
#    'buildingNumber': '65036',
#    'city': 'South Pollychester',
#    'zipcode': '22086-8642',
#    'country': 'Netherlands Antilles',
#    'county_code': 'UG',
#    'latitude': -83.326585,
#    'longitude': 130.876697},
#   'website': 'http://buckridge.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 97,
#   'firstname': 'Lily',
#   'lastname': 'Turner',
#   'email': 'stefan.collins@bechtelar.com',
#   'phone': '+9353646180161',
#   'birthday': '1979-12-29',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '53180 Bella Land Suite 132',
#    'streetName': 'Julian Flat',
#    'buildingNumber': '63566',
#    'city': 'Lake Melliebury',
#    'zipcode': '00773',
#    'country': 'Finland',
#    'county_code': 'MS',
#    'latitude': 73.513185,
#    'longitude': -81.721881},
#   'website': 'http://dicki.org',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 98,
#   'firstname': 'Jaida',
#   'lastname': 'Jones',
#   'email': 'johnston.jessika@hotmail.com',
#   'phone': '+1239091107008',
#   'birthday': '1959-11-05',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '9456 Larue Rapids',
#    'streetName': 'Wisozk Fork',
#    'buildingNumber': '9687',
#    'city': 'East Mayland',
#    'zipcode': '85532',
#    'country': 'Azerbaijan',
#    'county_code': 'PA',
#    'latitude': -43.39255,
#    'longitude': -92.385399},
#   'website': 'http://yost.com',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 99,
#   'firstname': 'Eloisa',
#   'lastname': 'Breitenberg',
#   'email': 'mcdermott.devin@gmail.com',
#   'phone': '+2428810297789',
#   'birthday': '1937-04-20',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '12314 Williamson Mountains Apt. 388',
#    'streetName': 'Benjamin Roads',
#    'buildingNumber': '329',
#    'city': 'New Ella',
#    'zipcode': '38554-7728',
#    'country': 'South Africa',
#    'county_code': 'CO',
#    'latitude': 87.44225,
#    'longitude': 133.344503},
#   'website': 'http://aufderhar.biz',
#   'image': 'http://placeimg.com/640/480/people'},
#  {'id': 100,
#   'firstname': 'Natalia',
#   'lastname': 'Price',
#   'email': 'yost.dave@yahoo.com',
#   'phone': '+9551101486270',
#   'birthday': '2020-01-12',
#   'gender': 'female',
#   'address': {'id': 0,
#    'street': '5604 Tromp Mount Suite 932',
#    'streetName': 'Robin Isle',
#    'buildingNumber': '68768',
#    'city': 'Lake Carolchester',
#    'zipcode': '99828-6198',
#    'country': 'Syrian Arab Republic',
#    'county_code': 'GY',
#    'latitude': -11.391388,
#    'longitude': -48.709162},
#   'website': 'http://hills.biz',
#   'image': 'http://placeimg.com/640/480/people'}]

# %% [markdown]
# ## Salvando os dados em um DataFrame PySpark

# %%
def data_from_api_to_df():
    data_list = get_data()
    try:
        df = (
            spark
            .createDataFrame(
                [Row(
                    id=data['id'],
                    nome=data['firstname'],
                    sobrenome=data['lastname'],
                    email=data['email'],
                    telefone=data['phone'],
                    data_nascimento=data['birthday'],
                    genero=data['gender'],
                    id_endereco=data['address']['id'],
                    endereco=data['address']['street'],
                    rua=data['address']['streetName'],
                    numero=data['address']['buildingNumber'],
                    cidade=data['address']['city'],
                    cep=data['address']['zipcode'],
                    pais=data['address']['country'],
                    cod_pais=data['address']['county_code'],
                    latitude=data['address']['latitude'],
                    longitude=data['address']['longitude'],
                    site=data['website'],
                    imagem=data['image']
                ) for data in data_list]
            )
        )
        return df
    except Exception as e:
        print(e)

# %%
df = data_from_api_to_df()

# %%
df.show(2)
# Out:
# +---+--------+---------+--------------------+--------------+---------------+------+-----------+--------------------+-------------+------+------------+-----+--------------------+--------+----------+----------+------------------+--------------------+
# | id|    nome|sobrenome|               email|      telefone|data_nascimento|genero|id_endereco|            endereco|          rua|numero|      cidade|  cep|                pais|cod_pais|  latitude| longitude|              site|              imagem|
# +---+--------+---------+--------------------+--------------+---------------+------+-----------+--------------------+-------------+------+------------+-----+--------------------+--------+----------+----------+------------------+--------------------+
# |  1|   Cyrus|     Hane|delaney.wisozk@st...|+9288929886870|     1994-06-10|  male|          0|2460 Bartoletti L...|  Brown Views| 73363|Dibbertmouth|99942|Antarctica (the t...|      SE|-26.746126|   28.7839|http://schmidt.biz|http://placeimg.c...|
# |  2|Kristian|     Yost|  margie14@yahoo.com|+5109017554291|     1960-05-23|  male|          0|64154 Dooley Ramp...|Phoebe Radial|   136|  New Kayley|14291|              Monaco|      NR|-25.771535|158.723025|http://farrell.biz|http://placeimg.c...|
# +---+--------+---------+--------------------+--------------+---------------+------+-----------+--------------------+-------------+------+------------+-----+--------------------+--------+----------+----------+------------------+--------------------+
# only showing top 2 rows

# %% [markdown]
# ## Salvando em CSV

# %%
(
    df
    .write
    .format("csv")
    .mode('overwrite')
    .save("consumer_data")
)

# %% [markdown]
# ## Salvando em Parquet

# %%
(
    df
    .write
    .format("parquet")
    .mode('overwrite')
    .save("consumer_data_parquet")
)

# %% [markdown]
# ## Salvando em json

# %%
(
    df
    .write
    .format("json")
    .mode('overwrite')
    .save("consumer_data_json")
)

# %% [markdown]
# ## Salvando os dados no MongoDB Atlas

# %% [markdown]
# ### Instalação do PyMongo

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.4.2-py3-none-any.whl.metadata (4.9 kB)
# Downloading pymongo-4.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (680 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.8/680.8 kB 5.1 MB/s eta 0:00:0000:0100:01m
# Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 8.3 MB/s eta 0:00:00:00:01
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.6.1

# %% [markdown]
# ### Importação do PyMongo

# %%
from pymongo.mongo_client import MongoClient

# %% [markdown]
# ### Conexão com o PyMongo

# %%
def conn_database(user, password):
    CONNECTRION_STRING = f"mongodb+srv://{user}:{password}@cluster0.oudmtpq.mongodb.net/retryWrites=true&w=majority"
    client = MongoClient(CONNECTRION_STRING)
    try:
        return client
    except Exception as e:
        print(e)
        return None

# %% [markdown]
# ### Pegando o Database

# %%
def get_database():
    try:
        conn_db = conn_database(user, password)
        db = conn_db['shop']
        return db
    except Exception as e:
        print(e)
        return None

# %% [markdown]
# ### Pegando a collection

# %%
def get_collection():
    try:
        db = get_database()
        collect = db['customer']
        return collect
    except Exception as e:
        print(e)
        return None

# %% [markdown]
# ### Inserindo os dados da API no MongoDB Atlas

# %%
dados = get_data()
insert = get_collection()

# %%
def insert_data_from_api_to_mongo():
    try:
        api_data = get_data()
        db_collection = get_collection()
        insert_data_mongo = db_collection.insert_many(api_data)
        print('OK')
    except Exception as e:
        print(e)
        return None

# %%
insert_data_from_api_to_mongo()
# Out:
# OK

# %% [markdown]
# ## Salvando os dados no AWS S3

# %% [markdown]
# ### Instância do S3 Bucket

# %%
S3 = boto3.client(
    's3', 
    aws_access_key_id = '',
    aws_secret_access_key = '',
    aws_session_token = '',
    region_name = 'us-east-1'
)

# %% [markdown]
# ### Criação do Bucket S3

# %%
def create_s3_buckets(*args):
    try:
        for bckt in args:
            bucket = S3.create_bucket(
                ACL = 'private', # Gerencia o acesso a bucekts e objetos do S3
                Bucket = bckt
            )
            print(bckt)
    except Exception as e:
        print(e)

# %%
def upload_file_to_s3(folder_name_source_files, bucket):
    import os

    try:
        source_file = os.getcwd() + '/' + folder_name_source_files + '/'
        list_files = os.listdir(source_file)
    
        for file in list_files:
            if '.csv' in file:
                up_file = S3.upload_file(
                    Filename = f'{source_file}{file}',
                    Bucket = bucket,
                    Key = file
                )
                print(file)
    except Exception as e:
        print(e)

# %%
create_s3_buckets('api_to_s3')

# %%
# nome da pasta ontem estão os arquivos
# nome do bucket
upload_file_to_s3('arquivos', 'api_to_s3')
